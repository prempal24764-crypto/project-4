# %%
import pandas as pd

url = "https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.csv"
df = pd.read_csv(url)

df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.to_csv("Housing_Data.csv", index=False)

# %% [markdown]
# 1️⃣ Title
#
# Housing Price Analysis using Python (EDA)

# %% [markdown]
# 2️⃣ Introduction (Text cell)
#
# Housing prices depend on various factors like area, rooms, parking, etc.
# This project analyzes housing data using Python to understand patterns, trends, and relationships between variables using visualizations.

# %% [markdown]
# 3️⃣ Objective
#
# Understand housing dataset
#
# Perform data cleaning
#
# Analyze price distribution
#
# Study relationship between features
#
# Visualize insights using graphs

# %% [markdown]
# 4️⃣ Tools Used
#
# Python
#
# Google Colab
#
# Pandas
#
# Matplotlib
#
# Seaborn

# %% [markdown]
# : Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# : Load Dataset (NO CSV PROBLEM SOLUTION)

# %%
url = "https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.csv"
df = pd.read_csv(url)
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %% [markdown]
# 3: Dataset Info

# %%
df.shape
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# ...

# %% [markdown]
# : Check Missing Values

# %%
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %% [markdown]
# 5: Univariate Analysis (Graph)

# %%
plt.figure()
sns.histplot(df['median_house_value'], kde=True)
plt.title("House Price Distribution")
plt.show()

# %% [markdown]
# ✍️ Observation:
# Most houses fall under a moderate price range.

# %% [markdown]
# 6: Area vs Price

# %%
plt.figure()
sns.scatterplot(x='median_income', y='median_house_value', data=df)
plt.title("Income vs House Price")
plt.show()

# %% [markdown]
# ✍️ Observation:
# Higher income areas generally have higher house prices.

# %% [markdown]
# 7: Correlation Heatmap

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Sirf numeric columns lo
numeric_df = df.select_dtypes(include='number')

plt.figure(figsize=(10,8))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# "correlation analysis was performed only on numerical columns to avoid issues caused by categorical variables.:"

# %% [markdown]
# 8: Feature Engineering

# %%
df['rooms_per_household'] = df['total_rooms'] / df['households']
df[['rooms_per_household']].head()
# Out:
#    rooms_per_household
# 0             6.984127
# 1             6.238137
# 2             8.288136
# 3             5.817352
# 4             6.281853

# %% [markdown]
#  CONCLUSION
#
# The analysis shows that housing prices are influenced by income, number of rooms, and location. Data visualization helped identify strong relationships between variables. This EDA can help in better understanding housing market behavior.
